# %%
print("Hello\nworld\\")
# Out:
# Hello
# world\

# %%
print("정규표현식에서 \d 는 숫자문자를 ...")
# Out:
# 정규표현식에서 \d 는 숫자문자를 ...
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\user\AppData\Local\Temp\ipykernel_276\2050848382.py:1: SyntaxWarning: invalid escape sequence '\d'
#   print("정규표현식에서 \d 는 숫자문자를 ...")

# %%
print("d")
# Out:
# d

# %%
print("\d")
# Out:
# \d
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\user\AppData\Local\Temp\ipykernel_276\668452119.py:1: SyntaxWarning: invalid escape sequence '\d'
#   print("\d")

# %%
print(r"\d") # \ -> \\
# Out:
# \d

# %%
print("Hello\nworld\\")
# Out:
# Hello
# world\

# %%
print(r"Hello\nworld\\")
# Out:
# Hello\nworld\\

# %%
import re

text = "apple banana cat"
result = re.findall(r"[abc]", text) # "apple banana cat"를 0부터 끝까지 "a", "b", "c" 중 일치하면 반환되는 리스트에 추가
print(result)
# ['a', 'b', 'a', 'a', 'a', 'c', 'a']
# Out:
# ['a', 'b', 'a', 'a', 'a', 'c', 'a']

# %%
import re

text = "apple banana cat"
result = re.findall(r"[xyz]", text) # "apple banana cat"를 0부터 끝까지 "a", "b", "c" 중 일치하면 반환되는 리스트에 추가
print(result)
# ['a', 'b', 'a', 'a', 'a', 'c', 'a']
# Out:
# []

# %%
import re

text = "apple banana cat"
result = re.findall(r"apple banana cat", text) # "apple banana cat"를 0부터 끝까지 "a", "b", "c" 중 일치하면 반환되는 리스트에 추가
print(result)
# ['a', 'b', 'a', 'a', 'a', 'c', 'a']
# Out:
# ['apple banana cat']

# %%
import re

text = "apple banana cat"
result = re.findall(r"apple", text) # "apple banana cat"를 0부터 끝까지 "a", "b", "c" 중 일치하면 반환되는 리스트에 추가
print(result)
# ['a', 'b', 'a', 'a', 'a', 'c', 'a']
# Out:
# ['apple']

# %%
import re

text = "apple banana cat"
result = re.findall(r"apple cat", text) # "apple banana cat"를 0부터 끝까지 "a", "b", "c" 중 일치하면 반환되는 리스트에 추가
print(result)
# ['a', 'b', 'a', 'a', 'a', 'c', 'a']
# Out:
# []

# %%
text = "apple banana cat"
result = re.findall(r"[at]", text)
if result:
    print("a나t가 있다")
else:
    print("a나t가 없다")
# Out:
# a나t가 있다

# %%
text = "apple banana cat"
result = re.search(r"[at]", text)
print(result)
if result:
    print("a나t가 있다")
else:
    print("a나t가 없다")
# Out:
# <re.Match object; span=(0, 1), match='a'>
# a나t가 있다

# %%
import re

text = "A12B34"
print(re.findall(r"[0-9]", text))
# Out:
# ['1', '2', '3', '4']

# %%
text = "Python JAVA AI"
print(re.findall(r"[A-Z]", text))
# Out:
# ['P', 'J', 'A', 'V', 'A', 'A', 'I']

# %%
text = "Python JAVA AI"
print(re.findall(r"[a-z]", text))
# Out:
# ['y', 't', 'h', 'o', 'n']

# %%
text = "Python JAVA AI"
print(re.findall(r"[a-zA-Z]", text))
# Out:
# ['P', 'y', 't', 'h', 'o', 'n', 'J', 'A', 'V', 'A', 'A', 'I']

# %%
text = "Python JAVA AI"
print(re.findall(r"[a-zA-Z0-9]", text))
# Out:
# ['P', 'y', 't', 'h', 'o', 'n', 'J', 'A', 'V', 'A', 'A', 'I']

# %%
# 소대소문자 포함, 특수문자 포함, 숫자문자 포함

import re

password = input("비밀번호:")

result = []

if not re.search(r"[a-z]", password):
    result.append("소문자가 없습니다")
    
if not re.search(r"[A-Z]", password):
    result.append("대문자가 없습니다")

if not re.search(r"[^0-9a-zA-Z]", password):
    result.append("특수문자가 없습니다")

if len(result) == 0:
    result.append("사용 가능한 비밀번호입니다.")

result
# Out:
# ['사용 가능한 비밀번호입니다.']

# %%
# 소대소문자 포함, 특수문자 포함, 숫자문자 포함

import re

password = input("비밀번호:")

result = []

if re.search(r"[가-힣]", password):
    result.append("한글을 사용할 수 없습니다")

if not re.search(r"[a-z]", password):
    result.append("소문자가 없습니다")
    
if not re.search(r"[A-Z]", password):
    result.append("대문자가 없습니다")

if not re.search(r"[^0-9a-zA-Z가-힣]", password):
    result.append("특수문자가 없습니다")

if len(result) == 0:
    result.append("사용 가능한 비밀번호입니다.")

result
# Out:
# ['한글을 사용할 수 없습니다']
